# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.arange(0,100)

plt.plot(x,x)

# %%
import numpy as np
import matplotlib.pyplot as plt
coords = np.array( [[1, 2],[2, 4],[3, 1]])

plt.title(label='Line chart')

plt.plot([i[0] for i in coords], [i[1] for i in coords], label="stuff")

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
import csv
import numpy as np

food=[]

with open('chipotle.csv', newline='') as f:
    reader = csv.DictReader(f, delimiter='\t')
    for row in reader:
        data = [row]
        food.append(data)

print(food[0])
# Out:
# [{'order_id': '1', 'quantity': '1', 'item_name': 'Chips and Fresh Tomato Salsa', 'choice_description': 'NULL', 'item_price': '$2.39 '}]
